# %% [markdown]
# ### <center>Datatypes in Python</center>
#
# #### Basic dataypes
# - Strings
# - Numbers
#
# #### Logical datatypes
#
# - Boolean: True, False
#
#
# #### NoneType
#
# None
#
# #### Advanced datatypes
#
# - Mappable : For example, dictionary
# - sequence : For example, list, tuple

# %% [markdown]
# #### What we will cover
#
# - Operations on datatypes
# - Changing data types (also called typecasting)
# - Variables
# - Assignment and comparisons operators
# - `dir()` function
# - How to see help of a paricular object
# - If else logic

# %% [markdown]
# #### The first command

# %%
print ('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# We can use both **"** and **'** to enclose a string. But, it is a good practice to use double quotes, because single quotes are frequently used in normal English language. Please see the examples below. Let's say you want to print

# %%
print ("It's morning!")
# Out:
# It's morning!

# %%
print ('First_row\n2nd_row')
# Out:
# First_row
# 2nd_row

# %% [markdown]
# #### Escape characters (\\)
# - \\ - backslash
# - \t - Tab
# - \n - new line

# %%
print ('It\'s morning')
# Out:
# It's morning

# %% [markdown]
# Let's say we want to print a Richard Fynman's quote:  "Study hard what interests you the most in the most undisciplined, irreverent and original manner possible."

# %%
print ("\"Study hard what interests you the most in the most undisciplined, irreverent and original manner possible.\"" )

# %%
print("My name is:\tX, and I appear before Y")
# Out:
# My name is:	X, and I appear before Y

# %%
print ("a\t\tc")
# Out:
# a		c

# %%
print ("Rate of Apple:\t50 units/Kg\nRate of Plum:\t10 units/kg\n")
# Out:
# Rate of Apple:	50 units/Kg
# Rate of Plum:	10 units/kg

# %% [markdown]
# #### Numbers
#
# Simple thought process exercises. Please think of any numbers that come in your mind.
#
# - How many students in a class?
#
# - How many goals Messy has scored?
#
# - How many litres of water I had today?
#
# - How many miles I walked in this week?
#
# - Does this bus go to University?
#
# - Is 5 greater than 7?
#
#
# Numbers primarily has three forms (except the coplex numbers):
#
# - Integers
#
# - Real (float)
#
# - Logical (True/False)

# %%
type(5.0)
# Out:
# float

# %%
type (5)
# Out:
# int

# %%
type (5.1)
# Out:
# float

# %%
5 >= 7
# Out:
# False

# %% [markdown]
# #### Strings
#
# A string is a bunch of characters within quotes (either single of dobule quote). For example, "Example string", 'DNA', 'RNA'. Python reads these characters in order. In Python, indexing starts with **0**. So, for "Example string", the positions would look like the following:
#
# "E" - 0 <br></br>"x" - 1<br></br>"a" - 2 <br></br>...<br></br>"e" - 6<br></br>" " - 7<br></br>"s" - 8<br></br>...<br></br>"g" - 13

# %% [markdown]
# ### Operations on datatypes
#
# - Addition (+)
# - Subtraction (-)
# - Multiplication (\*)
# - Division (/): quotient and remainder

# %%
5 + 7
# Out:
# 12

# %%
5 - 10
# Out:
# -5

# %%
5.0/2
# Out:
# 2.5

# %%
20//3
# Out:
# 6

# %%
13//4

# %%
5*2
# Out:
# 10

# %%
5**2
# Out:
# 25

# %%
25**(1/2)
# Out:
# 5.0

# %%
5 // 2
# Out:
# 2

# %% [markdown]
# #### Operations on strings

# %%
'2' + "3.5"
# Out:
# '23.5'

# %%
"2" - "3"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-4ba47df73700> in <module>
# ----> 1 "2" - "3"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
#print("2"*5)

"23"*5
# Out:
# '2323232323'

# %%
"2"*"3"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-5b54a2bacbf6> in <module>
# ----> 1 "2"*"5"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
"abc"
"xyz"
# Out:
# 'xyz'

# %%
print ("abc")
print ("xyz")
# Out:
# abc
# xyz

# %%
"2222"/"2"

# %%
x = "first string"
x = 5 
price_of_apple = 50 # Monday 
print (price_of_apple)
price_of_apple = 60 # Tuesday
print(price_of_apple)
# Out:
# 50
# 60

# %%
"2" + "3"

# %%
type (x)
# Out:
# int

# %%
dir(x)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %%
x + 5
# Out:
# 10

# %%
x.__add__(5)
# Out:
# 10

# %%
x.__add__(" second string")

# %%
dir(x)
5
# Out:
# 5

# %%
y = None

# %%
z = 5 + "3"

# %%
first_list = [1,2,3]

# %%
first_list.append(5)

# %%
first_list

# %%
how_we_get_none = first_list.append(5)

# %%
type (how_we_get_none)

# %%
print(how_we_get_none)

# %% [markdown]
# #### Variables

# %%
my_fav_fruit_price = 50

# %%
50_one = 51

# %%
my_fav_fruit_price = "50"

# %%
fifty = 50

# %%
salary = "5000.50"

# %%
x.__add__("50")

# %%
5 == 7

# %%
weather = "sunny"

if weather == "rainy":
    print("bring umbrella")
else:
    print ("no need to carry umbrella!")

# %%
list_of_genes = ['a', 'b', 'c'] 
list_of_expression_of_genes = [10, 20, 25]

# %%
dict_of_gene_and_expression = {'a' : 10, 'b': 20, 'c': 25}

# %%
dict_of_gene_and_expression['b']
# Out:
#   File "<ipython-input-60-fc15f2227fc1>", line 1
#     dict_of_gene_and_expression{'b'}
#                                ^
# SyntaxError: invalid syntax
