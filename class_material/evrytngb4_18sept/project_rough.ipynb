# %% [markdown]
# Project 1
# we have two files, shuf.a.bed and shuf.b.bed
# we need the selection criteria file
#
# we will make a temp file from the a and b for the genes containing
# the chromosomes that pass the selection criteria,
# then we will transfer them in output file as per the order of the
# chromosomes written in selection file.
